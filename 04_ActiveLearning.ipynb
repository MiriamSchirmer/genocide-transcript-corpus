# %% [markdown]
# # Active Learning

# %%
# %load_ext autoreload
# %autoreload 2

#########################################################################################
#########################################################################################
####### BEGIN OPTIONAL SECTION
#########################################################################################
#########################################################################################
GLB_INSTALL_DEPENDENCIES = True

if GLB_INSTALL_DEPENDENCIES:
    # !pip install transformers
    #!pip install torch
    #!pip install openpyxl
#########################################################################################
#########################################################################################
####### END OPTIONAL SECTION
#########################################################################################
#########################################################################################

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import src.classification_model_utilities as mlclassif_utilities

# %% [markdown]
# ## Execution of the **active learning** (update the parameters in the config file if necessary)

# %%
# !python src/active_learning.py
